# %% [markdown]
# # Finding Similar Items: Textually Similar Documents
#
# Eva Engel, Tori Leatherman
# November 14, 2022

# %% [markdown]
# ### Import Relevant Libraries & Predefined Classes

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import os
import time

import sys
sys.path.insert(0,"..")
from finding_textually_similar_documents.src.classes import shingling, compare_sets, min_hashing, compare_signatures, lsh
#from finding_textually_similar_documents.src.preprocessing import *

# %% [markdown]
# ### Set parameters for predefined classes

# %%
k_shingles = 10
n_signature = 500
n_documents = 100
sim_threshold = 0.8
n_bands = 100

#preprocessor = TextPreprocessor()
Shingling = shingling(k_shingles)
Min_hashing = min_hashing(n_signature)
LSH = lsh(n_bands, sim_threshold)

# %% [markdown]
# ### Import and read data
